RandomizedRemove='1.680847 2.005551 2.210437 2.713667 3.280029 3.990101 4.590377 5.093773 5.912549 7.449978 6.821827 8.374936 7.530074 8.817894 9.925208 10.548551 11.285638 13.078572 14.25517 14.215348 14.385666 15.395698 16.111149 17.570242 18.232994 18.513414 18.10198 20.798122 21.678572 22.079536 22.559366 22.366352 23.346636 24.142977 26.21232 27.260113 26.375317 27.354467 27.828987 28.711184 29.156776 30.990604 31.180222 27.50246 32.046448 28.632189 32.176525 34.39816 34.09649 34.63019 35.249863 39.660507 40.35245 43.446407 40.659504 42.65583 39.831806 46.506256 45.5016 45.68277' 
RandomizedGet='0.356635 0.624822 0.673886 0.83155 1.114377 1.313132 1.596187 1.776842 2.078089 2.460758 2.691043 2.943717 3.076713 3.316873 3.696108 4.001238 4.424164 4.983259 5.283033 5.660933 5.995506 6.453283 6.576061 6.810482 7.200275 7.258317 7.84866 7.949446 7.909263 9.015386 8.985736 9.063224 9.719675 10.75935 11.76319 12.05041 11.958027 10.743754 11.358881 11.916395 14.479044 14.159039 14.105858 14.422775 13.081993 13.981889 14.425314 19.295156 16.544373 15.588031 18.639305 18.315235 18.487509 18.504189 17.798433 17.55696 18.330828 19.555304 18.935104 19.688593'

# %%
p_put = list(map(float, randomized_put.split(' ')))
p_remove = list(map(float, randomized_remove.split(' ')))
p_get = list(map(float, randomized_get.split(' ')))
j_put = list(map(float, RandomizedPut.split(' ')))
j_remove = list(map(float, RandomizedRemove.split(' ')))
j_get = list(map(float, RandomizedGet.split(' ')))

# %%
plt.plot(ns, p_remove, 'C0', label='pytreemap remove()')
plt.plot(ns, p_put, 'C1', label='pytreemap put()')
plt.plot(ns, p_get, 'C2', label='pytreemap get()')
plt.title('pytreemap TreeMap put/remove/get operations benchmark')
plt.xlabel('Number of entries operated on')
plt.ylabel('Time (ms)')
plt.legend()
plt.savefig('pytreemap.png', dpi=300)

# %%
plt.plot(ns, j_remove, 'C3', label='Java remove()')
plt.plot(ns, j_put, 'C4', label='Java put()')
plt.plot(ns, j_get, 'C5', label='Java get()')
plt.title('Java TreeMap put/remove/get operations benchmark')
plt.xlabel('Number of entries operated on')
plt.ylabel('Time (ms)')
plt.legend()
plt.savefig('java.png', dpi=300)

# %%
plt.plot(ns, p_remove, 'C0', label='pytreemap remove()')
plt.plot(ns, p_put, 'C1', label='pytreemap put()')
plt.plot(ns, p_get, 'C2', label='pytreemap get()')
plt.plot(ns, j_remove, 'C3', label='Java remove()')
plt.plot(ns, j_put, 'C4', label='Java put()')
plt.plot(ns, j_get, 'C5', label='Java get()')
plt.title('Java vs pytreemap put/remove/get comparison')
plt.xlabel('Number of entries operated on')
plt.ylabel('Time (ms)')
plt.legend()
plt.savefig('java_vs_pytreemap.png', dpi=300)
